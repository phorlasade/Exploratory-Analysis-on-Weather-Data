# %% [markdown]
# ## Weather Forecast Analysis

# %% [markdown]
# **The weather dataset**
#
# The dataset encompasses a range of weather parameters, including temperature, humidity, wind speed, and more, providing a comprehensive overview of weather conditions across the country.
#
# **Dataset Description**
# - country - Country code (e.g., NG - Nigeria)
# - city - City name.
# - latitude - Latitude of the location.
# - longitude - Longitude of the location.
# - temp - Temperature in Kelvin.
# - temp_min - Minimum temperature at the moment.
# - temp_max - Maximum temperature at the moment.
# - pressure - Atmospheric pressure on the sea level, hPa.
# - humidity - Humidity, %.
# - sea_level - Atmospheric pressure on the sea level, hPa.
# - ground_level - Atmospheric pressure on the ground level, hPa.
# - wind_speed - Wind speed in meter/sec.
# - wind_degree - Wind direction, degrees.
# - sunrise - Sunrise time, unix, UTC.
# - sunset - Sunset time, unix, UTC.
# - rain_1h - Rain volume for the last 1 hour, mm.
# - rain_3h - Rain volume for the last 3 hours, mm.
# - timezone - Shift in seconds from UTC.
# - cloud - Cloudiness, %.
# - description - Weather condition within the group.
# - region - State in which the city belongs.
# - population - Estimated population in an area.

# %% [markdown]
# ## 1. Import Libraries

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# ## 2. Load Dataset

# %%
Cities_weather_df = pd.read_csv('nigeria-cities-weather-data.csv')

# %% [markdown]
# ## 3. Inspect Data

# %% [markdown]
# **`.head()`**

# %%
Cities_weather_df.head()
# Out:
#   country     city  latitude  longitude    temp  temp_min  temp_max  pressure  \
# 0      NG  Alodifi      7.14       5.33  303.98    303.98    303.98      1010
# 1      NG  Alodifi      7.18       5.41  303.98    303.98    303.98      1010
# 2      NG      Owo      7.30       5.52  303.88    303.88    303.88      1010
# 3      NG   Idanre      7.02       5.22  304.43    304.43    304.43      1010
# 4      NG      Owo      7.20       5.44  303.95    303.95    303.95      1010
#
#    humidity  sea_level  ...  wind_degree     sunrise      sunset  rain_1h  \
# 0        57       1010  ...          222  1708494876  1708537829      NaN
# 1        57       1010  ...          221  1708494858  1708537808      NaN
# 2        58       1010  ...          221  1708494837  1708537776      NaN
# 3        57       1010  ...          224  1708494897  1708537861      NaN
# 4        57       1010  ...          220  1708494852  1708537800      NaN
#
# ...

# %% [markdown]
# **`.tail()`**

# %%
Cities_weather_df.tail()
# Out:
#      country    city  latitude  longitude    temp  temp_min  temp_max  \
# 1836      NG  Fiditi      7.74       3.98  302.55    302.55    302.55
# 1837      NG  Ibadan      7.54       3.92  302.81    302.81    302.81
# 1838      NG  Fiditi      7.65       3.83  303.05    303.05    303.05
# 1839      NG  Fiditi      7.68       3.76  302.83    302.83    302.83
# 1840      NG  Fiditi      7.66       3.88  302.81    302.81    302.81
#
#       pressure  humidity  sea_level  ...  wind_degree     sunrise      sunset  \
# 1836      1009        48       1009  ...          235  1708495227  1708538126
# 1837      1009        48       1009  ...          226  1708495232  1708538149
# 1838      1009        47       1009  ...          229  1708495259  1708538166
# 1839      1009        47       1009  ...          229  1708495277  1708538181
# 1840      1009        48       1009  ...          230  1708495247  1708538154
#
#       rain_1h  rain_3h  timezone  cloud  description  region population
# ...

# %% [markdown]
# **`.sample()`**

# %%
Cities_weather_df.sample()
# Out:
#     country city  latitude  longitude    temp  temp_min  temp_max  pressure  \
# 861      NG  Ifo      6.93        3.3  306.28    306.28    306.28      1010
#
#      humidity  sea_level  ...  wind_degree     sunrise      sunset  rain_1h  \
# 861        53       1010  ...          229  1708495353  1708538326      NaN
#
#      rain_3h  timezone  cloud       description  region population
# 861      NaN      3600     44  scattered clouds    Ogun      12825
#
# [1 rows x 22 columns]

# %% [markdown]
# **`.shape`**

# %%
Cities_weather_df.shape
# Out:
# (1841, 22)

# %% [markdown]
# **`.columns`**

# %%
Cities_weather_df.columns
# Out:
# Index(['country', 'city', 'latitude', 'longitude', 'temp', 'temp_min',
#        'temp_max', 'pressure', 'humidity', 'sea_level', 'ground_level',
#        'wind_speed', 'wind_degree', 'sunrise', 'sunset', 'rain_1h', 'rain_3h',
#        'timezone', 'cloud', 'description', 'region', 'population'],
#       dtype='object')

# %% [markdown]
# **`.size`**

# %%
Cities_weather_df.size
# Out:
# 40502

# %% [markdown]
# **`.ndim`**

# %%
Cities_weather_df.ndim
# Out:
# 2

# %% [markdown]
# **`.info()`**

# %%
Cities_weather_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1841 entries, 0 to 1840
# Data columns (total 22 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   country       1841 non-null   object
#  1   city          1841 non-null   object
#  2   latitude      1841 non-null   float64
#  3   longitude     1841 non-null   float64
#  4   temp          1841 non-null   float64
#  5   temp_min      1841 non-null   float64
#  6   temp_max      1841 non-null   float64
#  7   pressure      1841 non-null   int64
#  8   humidity      1841 non-null   int64
#  9   sea_level     1841 non-null   int64
#  10  ground_level  1841 non-null   int64
#  11  wind_speed    1841 non-null   float64
#  12  wind_degree   1841 non-null   int64
#  13  sunrise       1841 non-null   int64
#  14  sunset        1841 non-null   int64
#  15  rain_1h       0 non-null      float64
#  16  rain_3h       0 non-null      float64
#  17  timezone      1841 non-null   int64
# ...

# %% [markdown]
# **`.dtypes`**

# %%
Cities_weather_df.dtypes
# Out:
# country          object
# city             object
# latitude        float64
# longitude       float64
# temp            float64
# temp_min        float64
# temp_max        float64
# pressure          int64
# humidity          int64
# sea_level         int64
# ground_level      int64
# wind_speed      float64
# wind_degree       int64
# sunrise           int64
# sunset            int64
# rain_1h         float64
# rain_3h         float64
# timezone          int64
# cloud             int64
# description      object
# region           object
# population        int64
# dtype: object

# %% [markdown]
# **`.unique()`** check the unique `description` feature of the dataset

# %%
Cities_weather_df['city'].unique()
# Out:
# array(['Alodifi', 'Owo', 'Idanre', 'Agbabu', 'Siluko', 'Emure-Ekiti',
#        'Ore', 'Ondo State', 'Ifon', 'Ondo', 'Omuo-Ekiti', 'Ilare',
#        'Igarra', 'Akure', 'Igbara-Odo', 'Ikere-Ekiti', 'Ijebu-Ife', 'Ode',
#        'Ifo', 'Owode', 'Otta', 'Ketu Adieowe', 'Abeokuta', 'Sagamu',
#        'Ijebu Ode', 'Epe', 'Ikeja', 'Ijebu-Igbo', 'Ilaro',
#        'Ebute Ikorodu', 'Imeko', 'Iperu', 'Ogun State', 'Isara', 'Ibadan',
#        'Ejirin', 'Aramoko-Ekiti', 'Ado-Ekiti', 'Ekiti State', 'Ise-Ekiti',
#        'Ipoti', 'Igede-Ekiti', 'Ifaki', 'Ijero-Ekiti', 'Efon-Alaaye',
#        'Omu-Aran', 'Lagos', 'Badagry', 'Fiditi', 'Lalupon', 'Orita Eruwa',
#        'Igbeti', 'Igbo-Ora', 'Igboho', 'Ogbomoso', 'Iseyin', 'Okeho',
#        'Kisi', 'Saki', 'Ago-Are'], dtype=object)

# %% [markdown]
# **`.nunique()`** check the number of unique `description` feature of the dataset

# %%
Cities_weather_df['city'].nunique()
# Out:
# 60

# %% [markdown]
# **`.value_counts()`** check the unique value in the `description` column and their counts.

# %%
Cities_weather_df['city'].value_counts()
# Out:
# city
# Agbabu           206
# Fiditi           156
# Epe              120
# Lagos             91
# Ifo               80
# Ibadan            69
# Owode             65
# Ketu Adieowe      63
# Ebute Ikorodu     62
# Owo               57
# Alodifi           53
# Idanre            50
# Ifaki             48
# Siluko            44
# Ijebu-Ife         43
# Omuo-Ekiti        39
# Ipoti             38
# Sagamu            37
# Otta              36
# Ejirin            33
# Ekiti State       31
# Ijebu-Igbo        31
# Ondo State        28
# Ilare             25
# Igarra            24
# Emure-Ekiti       20
# Ilaro             20
# Ijebu Ode         19
# Ifon              19
# Ondo              18
# Igede-Ekiti       15
# Ikeja             14
# Ado-Ekiti         14
# Abeokuta          14
# Ijero-Ekiti       13
# Ode               13
# Ore               13
# Ikere-Ekiti       13
# Lalupon           13
# Ise-Ekiti         12
# Ogun State        10
# Isara             10
# Efon-Alaaye        8
# ...

# %% [markdown]
# **`.duplicated()`**

# %%
Cities_weather_df.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 1836    False
# 1837    False
# 1838    False
# 1839    False
# 1840    False
# Length: 1841, dtype: bool

# %% [markdown]
# **`.duplicated().sum()`**

# %%
Cities_weather_df.duplicated().sum()
# Out:
# 354

# %% [markdown]
# **`.isnull()`**

# %%
Cities_weather_df.isnull()
# Out:
#       country   city  latitude  longitude   temp  temp_min  temp_max  \
# 0       False  False     False      False  False     False     False
# 1       False  False     False      False  False     False     False
# 2       False  False     False      False  False     False     False
# 3       False  False     False      False  False     False     False
# 4       False  False     False      False  False     False     False
# ...       ...    ...       ...        ...    ...       ...       ...
# 1836    False  False     False      False  False     False     False
# 1837    False  False     False      False  False     False     False
# 1838    False  False     False      False  False     False     False
# 1839    False  False     False      False  False     False     False
# 1840    False  False     False      False  False     False     False
#
#       pressure  humidity  sea_level  ...  wind_degree  sunrise  sunset  \
# ...

# %% [markdown]
# **`.isnull().sum()`**

# %%
Cities_weather_df.isnull().sum()
# Out:
# country            0
# city               0
# latitude           0
# longitude          0
# temp               0
# temp_min           0
# temp_max           0
# pressure           0
# humidity           0
# sea_level          0
# ground_level       0
# wind_speed         0
# wind_degree        0
# sunrise            0
# sunset             0
# rain_1h         1841
# rain_3h         1841
# timezone           0
# cloud              0
# description        0
# region             0
# population         0
# dtype: int64

# %% [markdown]
# **`.isna()`**

# %%
Cities_weather_df.isna()
# Out:
#       country   city  latitude  longitude   temp  temp_min  temp_max  \
# 0       False  False     False      False  False     False     False
# 1       False  False     False      False  False     False     False
# 2       False  False     False      False  False     False     False
# 3       False  False     False      False  False     False     False
# 4       False  False     False      False  False     False     False
# ...       ...    ...       ...        ...    ...       ...       ...
# 1836    False  False     False      False  False     False     False
# 1837    False  False     False      False  False     False     False
# 1838    False  False     False      False  False     False     False
# 1839    False  False     False      False  False     False     False
# 1840    False  False     False      False  False     False     False
#
#       pressure  humidity  sea_level  ...  wind_degree  sunrise  sunset  \
# ...

# %% [markdown]
# **`.isna().sum()`**

# %%
Cities_weather_df.isna().sum()
# Out:
# country            0
# city               0
# latitude           0
# longitude          0
# temp               0
# temp_min           0
# temp_max           0
# pressure           0
# humidity           0
# sea_level          0
# ground_level       0
# wind_speed         0
# wind_degree        0
# sunrise            0
# sunset             0
# rain_1h         1841
# rain_3h         1841
# timezone           0
# cloud              0
# description        0
# region             0
# population         0
# dtype: int64

# %% [markdown]
# ## Data Cleaning

# %% [markdown]
# ** remove the duplicate in the dataset

# %%
Cities_weather_df.drop_duplicates(inplace=True)

# %%
Cities_weather_df.shape
# Out:
# (1487, 22)

# %% [markdown]
# **`.drop()`** columns: rain_1h and rain_3h

# %%
Cities_weather_df.drop(['rain_1h','rain_3h'] , axis =1, inplace=True)

# %%
# confirm the columns of the dataset once more
Cities_weather_df
# Out:
#      country     city  latitude  longitude    temp  temp_min  temp_max  \
# 0         NG  Alodifi      7.14       5.33  303.98    303.98    303.98
# 1         NG  Alodifi      7.18       5.41  303.98    303.98    303.98
# 2         NG      Owo      7.30       5.52  303.88    303.88    303.88
# 3         NG   Idanre      7.02       5.22  304.43    304.43    304.43
# 4         NG      Owo      7.20       5.44  303.95    303.95    303.95
# ...      ...      ...       ...        ...     ...       ...       ...
# 1836      NG   Fiditi      7.74       3.98  302.55    302.55    302.55
# 1837      NG   Ibadan      7.54       3.92  302.81    302.81    302.81
# 1838      NG   Fiditi      7.65       3.83  303.05    303.05    303.05
# 1839      NG   Fiditi      7.68       3.76  302.83    302.83    302.83
# 1840      NG   Fiditi      7.66       3.88  302.81    302.81    302.81
#
#       pressure  humidity  sea_level  ground_level  wind_speed  wind_degree  \
# ...

# %%
Cities_weather_df.shape
# Out:
# (1487, 20)

# %% [markdown]
# **`.describe()`**

# %%
Cities_weather_df.describe()
# Out:
#           latitude    longitude         temp     temp_min     temp_max  \
# count  1487.000000  1487.000000  1487.000000  1487.000000  1487.000000
# mean      7.003900     4.334398   304.335999   304.335999   304.335999
# std       0.501167     0.802475     1.352452     1.352452     1.352452
# min       5.960000     2.840000   302.120000   302.120000   302.120000
# 25%       6.595000     3.715000   303.160000   303.160000   303.160000
# 50%       6.930000     4.090000   303.970000   303.970000   303.970000
# 75%       7.460000     5.090000   305.760000   305.760000   305.760000
# max       9.080000     5.960000   308.260000   308.260000   308.260000
#
#           pressure     humidity    sea_level  ground_level   wind_speed  \
# count  1487.000000  1487.000000  1487.000000   1487.000000  1487.000000
# mean   1009.737054    55.903833  1009.737054    991.448554     1.787377
# std       0.541786     6.047771     0.541786     17.941205     0.433228
# ...

# %% [markdown]
# **`.corr()`**

# %%
Cities_weather_df.corr(numeric_only=True)
# Out:
#               latitude  longitude      temp  temp_min  temp_max  pressure  \
# latitude      1.000000   0.261532 -0.471355 -0.471355 -0.471355 -0.024697
# longitude     0.261532   1.000000 -0.182763 -0.182763 -0.182763  0.628293
# temp         -0.471355  -0.182763  1.000000  1.000000  1.000000  0.019310
# temp_min     -0.471355  -0.182763  1.000000  1.000000  1.000000  0.019310
# temp_max     -0.471355  -0.182763  1.000000  1.000000  1.000000  0.019310
# pressure     -0.024697   0.628293  0.019310  0.019310  0.019310  1.000000
# humidity     -0.556093   0.269109 -0.079290 -0.079290 -0.079290  0.506960
# sea_level    -0.024697   0.628293  0.019310  0.019310  0.019310  1.000000
# ground_level -0.889006  -0.570295  0.532389  0.532389  0.532389 -0.248998
# wind_speed    0.136985   0.559338 -0.431379 -0.431379 -0.431379  0.228174
# wind_degree   0.429417   0.357179 -0.238832 -0.238832 -0.238832  0.104574
# sunrise      -0.145639  -0.992992  0.129625  0.129625  0.129625 -0.646995
# ...

# %% [markdown]
# ## Data Analysis

# %% [markdown]
# ### Q1). Find all the unique `wind_speed` value in the dataframe

# %%
Cities_weather_df['wind_speed'].unique()
# Out:
# array([1.93, 2.08, 2.34, 1.77, 2.14, 2.15, 1.76, 1.9 , 2.02, 2.1 , 1.96,
#        2.43, 2.32, 2.23, 2.03, 2.16, 1.53, 1.78, 2.37, 1.61, 2.93, 2.44,
#        2.72, 1.64, 1.65, 1.57, 2.55, 2.19, 2.28, 1.85, 1.8 , 1.58, 1.87,
#        3.  , 2.18, 1.84, 2.22, 2.26, 1.83, 2.31, 1.82, 3.03, 1.41, 2.29,
#        1.52, 1.62, 1.66, 1.88, 2.36, 2.81, 2.84, 1.43, 1.72, 1.44, 2.24,
#        1.81, 1.7 , 1.55, 2.78, 1.92, 2.  , 2.95, 2.87, 2.3 , 2.97, 3.01,
#        2.53, 1.38, 1.86, 2.89, 1.6 , 1.51, 1.67, 1.68, 1.39, 2.11, 1.47,
#        1.91, 1.4 , 1.5 , 1.63, 1.36, 1.98, 1.59, 2.04, 1.97, 1.49, 2.76,
#        2.74, 1.89, 2.35, 1.74, 2.01, 1.75, 2.5 , 2.45, 1.71, 2.48, 2.46,
#        2.56, 2.58, 2.17, 3.02, 1.54, 2.62, 1.34, 2.05, 1.28, 2.21, 1.46,
#        1.45, 2.07, 1.73, 1.69, 1.79, 1.94, 1.95, 2.86, 2.63, 2.6 , 2.33,
#        1.56, 2.39, 2.09, 2.13, 2.12, 2.2 , 2.66, 2.96, 2.59, 2.67, 2.38,
#        1.48, 1.42, 2.51, 2.42, 2.7 , 2.41, 2.25, 2.77, 2.06, 2.64, 2.98,
# ...

# %% [markdown]
# ### Q2). Find the mean, median, and mode of the `wind_speed`

# %%
Cities_weather_df.wind_speed.mean()
# Out:
# 1.7873772696704775

# %%
Cities_weather_df.wind_speed.median()
# Out:
# 1.72

# %%
Cities_weather_df.wind_speed.mode()
# Out:
# 0    1.62
# Name: wind_speed, dtype: float64

# %% [markdown]
# ### Q2). Find all the unique `description` value in the dataframe

# %%
Cities_weather_df['description'].unique()
# Out:
# array(['broken clouds', 'scattered clouds', 'overcast clouds',
#        'few clouds', 'clear sky'], dtype=object)

# %% [markdown]
# ### Q3). Find the numbers of time when the weathers are exactly clear sky

# %%
Cities_weather_df[Cities_weather_df['description'] == 'clear sky']
# Out:
#      country    city  latitude  longitude    temp  temp_min  temp_max  \
# 1673      NG  Fiditi      7.75       3.99  302.68    302.68    302.68
# 1821      NG  Fiditi      7.73       4.00  302.69    302.69    302.69
# 1836      NG  Fiditi      7.74       3.98  302.55    302.55    302.55
#
#       pressure  humidity  sea_level  ground_level  wind_speed  wind_degree  \
# 1673      1009        48       1009           978        1.63          236
# 1821      1009        48       1009           978        1.62          236
# 1836      1009        48       1009           976        1.64          235
#
#          sunrise      sunset  timezone  cloud description region  population
# 1673  1708495225  1708538123      3600     10   clear sky    Oyo       16371
# 1821  1708495222  1708538122      3600     10   clear sky    Oyo       14976
# 1836  1708495227  1708538126      3600     10   clear sky    Oyo       16900

# %%
Cities_weather_df[Cities_weather_df['description'] == 'clear sky'].nunique().sum()
# Out:
# 40

# %% [markdown]
# ### Q4). Find the number of times when the `wind_speed` was exactly 3m/sec.

# %%
Cities_weather_df[Cities_weather_df['wind_speed'] == 3].nunique().sum()
# Out:
# 32

# %% [markdown]
# ### Q5). Rename the column `description` to `weather_condition`.

# %%
Cities_weather_df.rename(columns = {'description': 'weather_condition'}, inplace=True)
Cities_weather_df
# Out:
#      country     city  latitude  longitude    temp  temp_min  temp_max  \
# 0         NG  Alodifi      7.14       5.33  303.98    303.98    303.98
# 1         NG  Alodifi      7.18       5.41  303.98    303.98    303.98
# 2         NG      Owo      7.30       5.52  303.88    303.88    303.88
# 3         NG   Idanre      7.02       5.22  304.43    304.43    304.43
# 4         NG      Owo      7.20       5.44  303.95    303.95    303.95
# ...      ...      ...       ...        ...     ...       ...       ...
# 1836      NG   Fiditi      7.74       3.98  302.55    302.55    302.55
# 1837      NG   Ibadan      7.54       3.92  302.81    302.81    302.81
# 1838      NG   Fiditi      7.65       3.83  303.05    303.05    303.05
# 1839      NG   Fiditi      7.68       3.76  302.83    302.83    302.83
# 1840      NG   Fiditi      7.66       3.88  302.81    302.81    302.81
#
#       pressure  humidity  sea_level  ground_level  wind_speed  wind_degree  \
# ...

# %% [markdown]
# ### Q6). What is the mean "temp"

# %%
Cities_weather_df['temp'].mean()
# Out:
# 304.3359986550101

# %% [markdown]
# ### Q7). what is the standard deviation of "pressure" in the data

# %%
Cities_weather_df['pressure'].std()
# Out:
# 0.5417857782065412

# %% [markdown]
# ### Q8). What is the variance of "Humidity" in the data

# %%
Cities_weather_df['humidity'].var()
# Out:
# 36.575537113484856

# %% [markdown]
# ### Q9). Find all instance where snow was recorded

# %%
Cities_weather_df[Cities_weather_df['weather_condition'] == 'snow'].nunique().sum()
# Out:
# 0

# %% [markdown]
# ### Q10). Find all instance where the wind_speed is above 3.5 and pressure above 300

# %%
Cities_weather_df[(Cities_weather_df['wind_speed'] > 3.5) & (Cities_weather_df['pressure'] > 300)]
# Out:
# Empty DataFrame
# Columns: [country, city, latitude, longitude, temp, temp_min, temp_max, pressure, humidity, sea_level, ground_level, wind_speed, wind_degree, sunrise, sunset, timezone, cloud, weather_condition, region, population]
# Index: []

# %% [markdown]
# ### Q11). What is the mean value of temp, pressure and humidity column against each 'weather condition"

# %%
def cal_mean():
    categories = Cities_weather_df['weather_condition'].unique()
    columns = ['temp', 'pressure', 'humidity']
    
    for col in columns:
        for cat in categories:
            mean = Cities_weather_df[Cities_weather_df['weather_condition'] == cat][col].mean()
            print(f"The mean of {col} by {cat} is :{np.round(mean,2)}")

# %%
cal_mean()
# Out:
# The mean of temp by broken clouds is :304.22
# The mean of temp by scattered clouds is :304.7
# The mean of temp by overcast clouds is :303.64
# The mean of temp by few clouds is :303.94
# The mean of temp by clear sky is :302.64
# The mean of pressure by broken clouds is :1010.07
# The mean of pressure by scattered clouds is :1009.63
# The mean of pressure by overcast clouds is :1010.0
# The mean of pressure by few clouds is :1009.25
# The mean of pressure by clear sky is :1009.0
# The mean of humidity by broken clouds is :59.02
# The mean of humidity by scattered clouds is :56.18
# The mean of humidity by overcast clouds is :57.25
# The mean of humidity by few clouds is :49.03
# The mean of humidity by clear sky is :48.0

# %% [markdown]
# ### Q12). What is the minimum and maximum value of temp column against each weather condition?

# %%
def cal_min_max():
    categories = Cities_weather_df['weather_condition'].unique()
    

    for cat in categories:
        min_val = Cities_weather_df[Cities_weather_df['weather_condition'] == cat]['temp'].min()
        max_val = Cities_weather_df[Cities_weather_df['weather_condition'] == cat]['temp'].max()
        print(f"The minimum and maximum of temp by {cat} is : {min_val} and {max_val}")

# %%
cal_min_max()
# Out:
# The minimum and maximum of temp by broken clouds is : 302.12 and 306.29
# The minimum and maximum of temp by scattered clouds is : 302.26 and 307.9
# The minimum and maximum of temp by overcast clouds is : 302.69 and 304.18
# The minimum and maximum of temp by few clouds is : 302.27 and 308.26
# The minimum and maximum of temp by clear sky is : 302.55 and 302.69

# %% [markdown]
# ## Data Visualization

# %% [markdown]
# ### Q13).  Visualize the distribution of the temp, pressure, humidity, sea_level, ground_level, wind_speed and population column**
#
# a. using histogram
# b. using boxplot

# %% [markdown]
# ### Q14).  Visualize the average  temp by each region

# %% [markdown]
# ### Q15).  Visualize the average  pressure by each region

# %% [markdown]
# ### Q16).  Visualize the count of city by each region
